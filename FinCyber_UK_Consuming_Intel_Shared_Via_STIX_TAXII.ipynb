# %% [markdown]
# # CYTAXII2, Cyware's TAXII 2.x Client
#
# cytaxii2 is a pip library [for python 3] by Cyware that can be used to connect to and, discover, get collections, poll and inbox data from and to a TAXII 2.x server. This supports stix/taxii 2, 2.1
#
# A pair of TAXII credentials can be received at https://cyware.com/resources/threat-intel-feeds

# %% [markdown]
# This library supports python3 and can be installed by "pip3 install cytaxii2". After installation the library can be imported as follows:

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
import json

# %%
import requests

"""
Cyware TAXII 2.0/ 2.1 Client
TAXII Supported Version: 2.0 & 2.1
"""


class cytaxii2(object):
    def __init__(self, discovery_url, username, password, version=2.1, **kwargs):
        """
        This method is used to initialize values throughout the class
        :param discovery_url: Enter the TAXII 2.1 Discovery URL
        :param username: Enter the username to to authenticate with
        :param password: Enter the password to to authenticate with
        """
        if version == 2.1:
            self.headers = {
                'Content-Type': 'application/taxii+json;version=2.1',
                'User-Agent': 'cyware.taxii2client',
                'Accept': 'application/taxii+json;version=2.1'
            }
        elif version == 2.0:
            self.headers = {
                'Content-Type': 'application/vnd.oasis.stix+json; version=2.0',
                'User-Agent': 'cyware.httpclient',
                'Accept': 'application/vnd.oasis.taxii+json; version=2.0'
            }
        else:
            raise SyntaxError("Invalid version entered. Only TAXII versions 2.0 and 2.1 are supported")

        self.discovery_url = discovery_url
        self.auth = (username, password)
        self.collections = "collections"
        self.objects = "objects"

    def request_handler(self, method, url, json_data=None, query_params=None, **kwargs):
        """
        This method is used to handle all TAXII requests
        :param query_params: Any query params to pass
        :param method: Enter the HTTP method to use
        :param url: Enter the URL to make the request to
        :param json_data: Enter the json data to pass as a payload
        """
        try:
            if method == 'GET':
                response = requests.get(url=url, data=json_data, headers=self.headers, auth=self.auth,
                                        params=query_params)
            elif method == 'POST':
                response = requests.post(url=url, data=json_data, headers=self.headers, auth=self.auth,
                                         params=query_params)
            else:
                return {
                    'response': 'Unsupported Method requested',
                    'status': False,
                    'status_code': 405
                }

            status_code = response.status_code

            if response.ok:
                response_json = response.json()
                status = True
            else:
                response_json = response.text
                status = False

        except Exception as e:
            status_code = 'EXCEPTION'
            response_json = str(e)
            status = False

        return {
            'response': response_json,
            'status': status,
            'status_code': status_code
        }

    def discovery_request(self, **kwargs):
        """
        This method is used to make a request to the TAXII discovery URL
        """
        response = self.request_handler(method='GET', url=self.discovery_url)
        return response

    def root_discovery(self, **kwargs):
        """
        This method is used to make a root discovery request to the TAXII URL
        """
        discover_response = self.discovery_request()
        if discover_response['status_code'] == 200:
            api_root = discover_response['response']['default']
            response = self.request_handler(method='GET', url=api_root)
            return response
        else:
            return discover_response

    def collection_request(self, **kwargs):
        """
        This method is used to make a request to the TAXII server to get all collections on the server
        """
        collection_url = "{0}/{1}/".format(self.discovery_url.rstrip("/"), self.collections)
        response = self.request_handler(method='GET', url=collection_url)
        return response

    def collection_data_request(self, collection_id, **kwargs):
        """
        This method is used to get data about a particular collection on the TAXII server
        :param collection_id: Enter the collection ID
        """
        poll_url = "{0}/{1}/{2}/".format(self.discovery_url.rstrip("/"), self.collections, collection_id)
        response = self.request_handler(method='GET', url=poll_url)
        return response

    def poll_request(self, collection_id, added_after=None, limit=None, object_id=None, next=None, object_type=None,
                     **kwargs):
        """
        This method is used to poll data from a particular collection
        :param object_type: Enter the indicator type to retrieve
        :param next: Enter the next integer if the data has been paginated
        :param object_id: Enter a specific object to retrieve
        :param limit: Enter response limit
        :param added_after: Enter the date to poll from, polls all data if left blank
        :param collection_id: Enter the collection ID
        """
        params = {
            'added_after': added_after,
            'limit': limit,
            'next': next,
            'match[id]': object_id,
            'match[type]': object_type
        }
        poll_url = "{0}/{1}/{2}/{3}/".format(self.discovery_url.rstrip("/"), self.collections, collection_id, self.objects)
        response = self.request_handler(method='GET', url=poll_url, query_params=params)
        return response

# %% [markdown]
# After importing, we have to create an object with the TAXII URL, username and password and TAXII version [2.0/ 2.1], as follows:

# %%
cytaxii_object = cytaxii2(
    discovery_url='https://threatfeed.cyware.com/ctixapi/ctix21/',
             username='<username>',
             password='<password>',
             version=2.1, verify=False)

# %% [markdown]
# After the object is created we can call the methods present in the library. Each of the methods are highlighted below.

# %% [markdown]
# The first method is where we can perform a TAXII discovery request and can be done as follows.
#
# ##### Arguments
# None

# %%
discovery_response = cytaxii_object.discovery_request()
print(json.dumps(discovery_response, indent=4))
# Out:
# {
#     "response": {
#         "title": "ThreatFeed TAXII 2.1 API Root",
#         "description": "TAXII 2.1 service for ThreatFeed user",
#         "versions": [
#             "application/taxii+json;version=2.1"
#         ],
#         "max_content_length": 10000000
#     },
#     "status": true,
#     "status_code": 200
# }

# %% [markdown]
# Next, we can perform a collection request, where we request all STIX data collections from the TAXII server. We must note in TAXII all data is held inside a collection and a list of collections can be requested as follows.
#
# ##### Arguments
# None

# %%
collections = cytaxii_object.collection_request()
print(json.dumps(collections, indent=4))
# Out:
# {
#     "response": {
#         "collections": [
#             {
#                 "id": "46cc884e-fd37-4436-95b3-ac73710df3dc",
#                 "title": "ThreatFox",
#                 "description": "ThreatFox is a project operated by abuse.ch. The purpose of the project is to collect and share indicators of compromise (IOCs), helping IT-security researchers and threat analysts protecting their constituency and customers from cyber threats.",
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "52ab6ed4-83d0-42fb-891c-708221648181",
#                 "title": "default",
#                 "description": "Default collection of ctix",
#                 "can_read": true,
#                 "can_write": true,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "1ae57e3d-810c-450c-a97f-eb60b63c896c",
#                 "title": "Malware Bazaar",
#                 "description": "Server STIX collection for Malware Bazaar",
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "694bc05f-9568-4738-ac66-7c3fb119ff75",
#                 "title": "Das Malwerk",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "8eafbfb4-6213-4ff8-9de4-978aa5fdc59f",
#                 "title": "Stop Forum Spam",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "ebf09405-9e6d-45ae-a6c0-038492af3ee8",
#                 "title": "Ipsum",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "ffa5a722-0e00-41de-9b70-b1fbeed9ff9f",
#                 "title": "Neo23x0",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "8f14d378-f537-491f-ae82-68580fcfb73a",
#                 "title": "Dataplane",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "34e7e24a-1bad-48f1-b88d-bdfd5f99a6bd",
#                 "title": "VoIPBL",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "4656fc49-0ff8-460e-8aff-1be93b0a488f",
#                 "title": "Darklist De",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "ab7c3de4-5368-4e87-9dc4-32ff37f14590",
#                 "title": "Sblam",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "557bb369-e002-4d99-9908-d709a45b9e56",
#                 "title": "Project HoneyPot",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "c0cf066e-3ad7-4723-8034-15cd28d4194a",
#                 "title": "CINS Score",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "81a20383-0147-4b3a-94a9-ebf13a12ff88",
#                 "title": "Pgl Yoyo",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "dd37a39e-42cc-42a1-9ca5-fd494b8a3100",
#                 "title": "Brute Force Blocker",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "ed26345f-365c-401c-919b-c1c216e78b00",
#                 "title": "Botscout",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "6ab49abf-a67b-42cd-a90c-045644a515c0",
#                 "title": "Cyware Vulnerability Feed",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "007cc299-9600-4ff4-ab0b-83c734903041",
#                 "title": "Talos Intelligence",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "b47bafb6-f8b3-4707-9c10-1fbe9550e2a3",
#                 "title": "Dshield",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "8de5d7d7-1c5a-4d81-9110-aa2e10bd74dc",
#                 "title": "Cyber Cure",
#                 "description": "cybercure_collection",
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "af63b2ef-2b08-4d11-a2a4-2c913eafebce",
#                 "title": "Emerging Threats Fwip",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "5ea46dc9-bdff-45c8-a7b1-bfd925799e80",
#                 "title": "Tor Feed",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "0824ead0-73f0-4b49-83ad-109077a2a4a5",
#                 "title": "Honey Db",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "c208ded2-ecac-41d3-9d68-9c4941bc0520",
#                 "title": "Botvrij",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "57bb261a-417e-47df-abb5-db5755db969a",
#                 "title": "VirusShare",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "edfb8789-4123-405b-a074-941c98ff1037",
#                 "title": "Binary Defense Banlist",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "ce1d5d4a-4ea8-4479-a0c0-bc7dbdffe6e1",
#                 "title": "Phishtank",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "5c196ffb-5e07-42e6-b633-7d6e07f4120b",
#                 "title": "Malshare",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "9dc267ed-e7cd-4e2c-8d0e-6536a8b68d53",
#                 "title": "Abuse.ch SSL",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "f50c9e8a-2fdd-49be-884d-547713b9ec37",
#                 "title": "Blocklist De",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "c459cb37-a52f-4e22-9e61-e5d781a2d6d6",
#                 "title": "OpenPhish",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "9142afa9-a320-4ae9-b2e5-9f4cebbf0b02",
#                 "title": "Greensnow",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "7b2df77e-09d7-4311-bebc-6a4f3a18c417",
#                 "title": "Dan Tor",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "8a8723f3-1239-4d30-b9a5-3dc44a513b50",
#                 "title": "Url Haus",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "62b47777-1416-493a-aaa0-cb500c5a64c8",
#                 "title": "Vxvault",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "f9f25677-588a-4db7-b3d5-42bab03c4d19",
#                 "title": "Snort Feed",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "39d4411c-5727-4d79-89d6-12bc3a2ae129",
#                 "title": "Pop3 Gropers",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "23adb570-86e8-4307-95c4-ca503247933b",
#                 "title": "Feodo",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "c87ba8b3-321a-440b-9f7c-f06ff7e9fe51",
#                 "title": "Emerging Threats",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "8332ed3d-935a-4211-8da1-7f6ddc40fd97",
#                 "title": "Cybercrime Tracker",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             },
#             {
#                 "id": "da01d857-df1a-484a-b5fa-f0426b5880af",
#                 "title": "Coin Blocker",
#                 "description": null,
#                 "can_read": true,
#                 "can_write": false,
#                 "media_types": [
#                     "application/stix+json;version=2.1"
#                 ]
#             }
#         ]
#     },
#     "status": true,
#     "status_code": 200
# }

# %% [markdown]
# Next, we can also get data about a particular TAXII collection URL and this can be done as follow.
#
# ##### Arguments:
# - collection_id: Enter the collection ID to get details of __[mandatory]__

# %%
collection_data = cytaxii_object.collection_data_request(collection_id="46cc884e-fd37-4436-95b3-ac73710df3dc")
print(json.dumps(collection_data, indent=4))
# Out:
# {
#     "response": {
#         "id": "46cc884e-fd37-4436-95b3-ac73710df3dc",
#         "title": "ThreatFox",
#         "description": "ThreatFox is a project operated by abuse.ch. The purpose of the project is to collect and share indicators of compromise (IOCs), helping IT-security researchers and threat analysts protecting their constituency and customers from cyber threats.",
#         "can_read": true,
#         "can_write": false,
#         "media_types": [
#             "application/stix+json;version=2.1"
#         ]
#     },
#     "status": true,
#     "status_code": 200
# }

# %% [markdown]
# Next, we can get data from a TAXII collection. This is one of the most important use cases, where we can poll data from a TAXII server.
#
# ##### Arguments:
# - collection_id: Enter the collection ID to get details of __[mandatory]__
# - added_after: Enter a datetime string to parse. Data will be returned only after this date till current data. Defaults to all data
# - limit: Enter the number of responses to return
# - object_id: Enter the object_id. This param will limit the response to only this object in the response
# - object_type: Enter the object type to return
# - next: If the data is paginated, the "next" param can be used to get additional data

# %%
poll_response = cytaxii_object.poll_request(collection_id='ce1d5d4a-4ea8-4479-a0c0-bc7dbdffe6e1', limit=10, added_after="01-01-2024")
print(json.dumps(poll_response, indent=4))
# Out:
# {
#     "response": {
#         "objects": [
#             {
#                 "id": "marking-definition--34098fce-860f-48ae-8e50-ebd3cc5e41da",
#                 "name": "TLP:GREEN",
#                 "type": "marking-definition",
#                 "created": "2017-01-20T00:00:00.000Z",
#                 "definition": {
#                     "tlp": "green"
#                 },
#                 "spec_version": "2.1",
#                 "definition_type": "tlp"
#             },
#             {
#                 "id": "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82",
#                 "name": "TLP:AMBER",
#                 "type": "marking-definition",
#                 "created": "2017-01-20T00:00:00.000Z",
#                 "definition": {
#                     "tlp": "amber"
#                 },
#                 "spec_version": "2.1",
#                 "definition_type": "tlp"
#             },
#             {
#                 "id": "indicator--5eca3ac6-0e74-4b9c-9a2c-a09e19104667",
#                 "name": "None",
#                 "type": "indicator",
#                 "created": "2024-04-26T08:21:18.000Z",
#                 "pattern": "[url:value = 'https://www.dropbox.com/c/scl/fi/uph9kp0ie2xoxfu9iaeqo/BT-BROADBAND.paper?rlkey=xs3l4h55mr4ej27dyseaq49uk&dl=0']",
#                 "revoked": false,
#                 "modified": "2024-04-26T09:09:50.000Z",
#                 "confidence": 100,
#                 "extensions": {
#                     "extension-definition--5c4546f1-7e76-4b4a-844c-64a1f722c788": {
#                         "extension_type": "toplevel-property-extension"
#                     }
#                 },
#                 "valid_from": "2024-04-26T13:07:44.515Z",
#                 "pattern_type": "stix",
#                 "spec_version": "2.1",
#                 "indicator_types": [
#                     "unknown"
#                 ],
#                 "x_ctix_confidence_score": 100,
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--d8653759-b47c-4cef-b21a-602619e8cd76",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:44.519Z",
#                 "modified": "2024-04-26T13:07:44.519Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--5eca3ac6-0e74-4b9c-9a2c-a09e19104667",
#                 "target_ref": "indicator--2a2986d6-208b-47ac-b875-c18a0d0e92c6",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--58909d9e-794d-4d4c-a882-46b77022cff8",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:52.653Z",
#                 "modified": "2024-04-26T13:07:52.653Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--f32c783b-46a2-4600-a108-1e7517efa3c7",
#                 "target_ref": "indicator--19852523-8810-4879-acc1-65e70a4159f2",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--226b45e2-0132-438d-9be5-f566009e5d1f",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:59.432Z",
#                 "modified": "2024-04-26T13:07:59.432Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--0c8c6e3d-f17e-4d7f-9b4c-a1834d220efd",
#                 "target_ref": "indicator--b06236c8-bd88-4ca8-872b-c582ef742026",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--8799f32a-3b64-4b2a-be78-e4225de4f63f",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:08.625Z",
#                 "modified": "2024-04-26T13:07:08.625Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--431efd1d-a0f5-4949-883d-787184abd769",
#                 "target_ref": "indicator--5fdc50cb-8e6e-4e4a-92c0-f98186452efa",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--07c7acfe-0ce5-4c7c-b8d8-d63dd5570701",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:09.285Z",
#                 "modified": "2024-04-26T13:07:09.285Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--7254c6bb-214d-4c24-a84a-96e77d9f050f",
#                 "target_ref": "indicator--6cf3536c-5abd-4133-b429-3f17c882113f",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--1000b1c7-07f6-458d-9521-63bf6d96a42f",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:16.664Z",
#                 "modified": "2024-04-26T13:07:16.664Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--838633f7-00d0-495b-b0ef-60f9e3a3c016",
#                 "target_ref": "indicator--d1539d8c-8f12-4503-8c44-09877f4c1a28",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--b8a83592-3c0f-414d-9708-2f0a6368d6a3",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:40.917Z",
#                 "modified": "2024-04-26T13:07:40.917Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--46a8167c-1626-4a6d-8dfb-99121661b2c3",
#                 "target_ref": "indicator--0b4fa6d5-09c5-4ca9-b58d-ae4fa41aa461",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--41e2e353-c227-40b0-8c30-b0667d8e0d62",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:48.595Z",
#                 "modified": "2024-04-26T13:07:48.595Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--d40f6428-b47a-4e6a-bfe8-1869a821f56a",
#                 "target_ref": "indicator--3abe9cf6-c8ae-4430-a186-8af1094f1c89",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             },
#             {
#                 "id": "relationship--ef7c724b-0c61-4a0f-9d36-66487d0e350a",
#                 "type": "relationship",
#                 "created": "2024-04-26T13:07:54.294Z",
#                 "modified": "2024-04-26T13:07:54.294Z",
#                 "confidence": 100,
#                 "source_ref": "indicator--40d72c95-42e3-408f-8608-0995818efb09",
#                 "target_ref": "indicator--b154887f-d339-46f0-8d2b-f6c7430ea1e9",
#                 "spec_version": "2.1",
#                 "relationship_type": "related-to",
#                 "object_marking_refs": [
#                     "marking-definition--f88d31f6-486f-44da-b317-01333bde0b82"
#                 ]
#             }
#         ],
#         "more": true,
#         "next": "8381729"
#     },
#     "status": true,
#     "status_code": 206
# }
